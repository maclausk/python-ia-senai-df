# %% [markdown]
# #### 28/06-2024 - Curso Desenvolvedor Python - SENAI- Taguatinga-DF
#
# #### Criando Ambiente Para Stack Profissional
#
# ![Capa](images/capa.png)
#
# > *Este eBook fornece um guia passo a passo para configurar um ambiente de desenvolvimento em Python, adequado para cientistas de dados e desenvolvedores. Inclui instruções detalhadas e exemplos para facilitar o entendimento, tornando-o acessível até para aqueles que estão começando.*
#
# ---
#
# ##### Sumário
#
# 1. Instalação do Python 3.12.4
# 2. Instalação do Visual Studio Code (VSCode)
# 3. Instalação da Extensão Python no VSCode
# 4. Criar Ambiente Virtual
# 5. Ativar a Extensão "Material Icon Theme" no VSCode
# 6. Instalação do Jupyter
# 7. Observações sobre Ambientes Virtuais
#
# ---
#
# ##### Passo 1: Instalação do Python 3.12.4
#
# Baixe e instale a versão 3.12.4 do Python a partir do site oficial pelo [link](https://www.python.org/ftp/python/3.12.4/python-3.12.4-amd64.exe). Certifique-se de marcar a opção 'Add Python to PATH' durante a instalação. Isso permite que o Python seja acessado de qualquer local no sistema.
#
# ![Instalação do Python](images/instpython.png)
#
# *Instalação do Python 3.12.4*
#
# ---
#
# ##### Passo 2: Instalação do Visual Studio Code (VSCode)
#
# Baixe e instale o Visual Studio Code a partir do site oficial pelo [link](https://vscode.download.prss.microsoft.com/dbazure/download/stable/5437499feb04f7a586f677b155b039bc2b3669eb/VSCodeUserSetup-x64-1.90.2.exe).
#
# O Visual Studio Code é um editor de código-fonte poderoso e extensível. Ele é amplamente utilizado por desenvolvedores para escrever código em várias linguagens.
#
# ![Instalação do Visual Studio Code](images/instvsc.png)
#
# *Instalação do Visual Studio Code*
#
# ---
#
# ##### Passo 3: Instalação da Extensão Python no VSCode
#
# Abra o VSCode, vá para a aba de extensões e procure por 'Python'. Instale a extensão oficial da Microsoft para suporte a Python, que oferece recursos de depuração e execução de scripts Python.
#
# ![Instalação da Extensão Python no VSCode](images/extpytvscode.png)
#
# *Instalação da Extensão Python no VSCode*
#
# ---
#
# ##### Passo 4: Criar Ambiente Virtual
#
# - Um ambiente virtual isola as dependências do seu projeto, evitando conflitos entre diferentes versões de pacotes.
# - No VSCode, use a barra de pesquisa para criar um ambiente virtual ou use o comando "Control+Shift+P", onde deve ser escolhida a opção '.venv' e em seguida a linguagem Python.
#
# Para ativar o ambiente virtual: Execute o comando 'activate' no terminal, via prompt de comando, seguindo o seguinte exemplo: '\.venv\Scripts\activate'.
#
# ![Ativação do ambiente virtual](images/jupyter1.png)
#
# Para desativar o ambiente virtual: Execute o comando 'activate' no terminal, via prompt de comando, seguindo o seguinte exemplo: '\.venv\Scripts\activate'.
#
# ![Desativando o ambiente virtual](images/jupyter4.png)
#
# ---
#
# ##### Passo 5: Ativar a Extensão 'Material Icon Theme' no VSCode
#
# No VSCode, instale a extensão 'Material Icon Theme' para uma visualização mais limpa e organizada dos ícones dos diretórios, melhorando a experiência de navegação.
#
# ![Ativar a Extensão 'Material Icon Theme' no VSCode](images/materialicon.png)
#
# *Ativar a Extensão 'Material Icon Theme' no VSCode*
#
# ![Extensão 'Material Icon Theme' no VSCode Ativa](images/materialicon2.png)
#
# *Extensão 'Material Icon Theme' no VSCode Ativa*
#
# ---
#
# ##### Passo 6: Instalação do Jupyter
#
# No terminal do VSCode, após ativação do ambiente virtual é necessário instalar as extensões Jupyter e JupyterLab. O Jupyter é usado para criar e executar notebooks interativos, ideal para cientistas de dados enquanto o Jupyter Lab é uma poderosa ferramenta de desenvolvimento que oferece um ambiente interativo para programação em Python e outras linguagens
#
#
# *Ativação do Jupyter e JupyterLAb*
#
# ![Instalação do Jupyter e JupyterLab](images/jupyter2.png)
#
# ![Instalação do Jupyter e JupyterLab](images/jupyter3.png)
#
# ---
#
# ##### 7: Observações Importantes
#
# **Notebooks:** São como cadernos digitais onde você pode escrever e executar código passo a passo. Eles ajudam a combinar explicações e gráficos em um só lugar, tornando o aprendizado e a análise de dados mais fáceis e interativos.
#
# **Por que usar um ambiente virtual?**
# - **Isolamento**: Garante que os pacotes e suas versões sejam específicos para cada projeto, evitando problemas com outros projetos.
# - **Organização**: Facilita a gestão de dependências, mantendo seu ambiente de desenvolvimento limpo e organizado.
#
# **Por que desativar o ambiente virtual?**
# - **Recursos**: Libera memória e processamento quando não está usando o projeto.
# - **Flexibilidade**: Permite alternar para outros projetos que podem ter suas próprias configurações.
# - **Consistência**: Assegura que o projeto use as mesmas versões de pacotes sempre que você trabalhar nele.
# - **Evitar Conflitos**: Previne problemas com pacotes de outras partes do sistema.
#
# ---
