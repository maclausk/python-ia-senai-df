# %% [markdown]
# #### Semana de Ciência de Dados com Python/IA - SENAI-DF - Vespertino - 23/07/2024 - Marcelo Pereira Avelino
# ##### 📝 Orientação a Objetos

# %% [markdown]
# `Aspectos Básicos da Orientação a Objetos em Python`

# %% [markdown]
# Este arquivo apresenta os aspectos básicos da Orientação a Objetos em Python.
#
# 1. Definindo uma Classe
# 2. Método __init__
# 3. Métodos em uma Classe
# 4. Atributos de Instância
# 5. Utilizando a Referência 'self'

# %%
class Imovel:
    def __init__(self,preco):
        self.preco = preco
        
    def alugar(self):
        return 'aluguei!'

# %%
# Objeto | Chamada ao Construtor
casa = Imovel(preco=345.78)
casa.preco
# Out:
# 345.78

# %%
# Método
print(casa.alugar())
# Out:
# aluguei!

# %%
# Definindo uma Classe
# Classe: É um modelo para criar objetos (instâncias). Ela define um conjunto de atributos e métodos que os objetos criados a partir dela terão.

class Mamifero:  # Define a classe Mamifero, que é um grupo de objetos semelhantes.
                 # Nesse caso, a classe Mamifero representa um conjunto de animais com características e comportamentos comuns.
    
    # O método __init__ também chamado de construtor, é um método especial que é executado automaticamente quando um novo objeto da classe é criado.
    def __init__(self, nome_popular, idade, cor): # self representa a instância atual da classe. É usado para acessar atributos e métodos da classe.
                                                  # nome_popular, idade e cor são atributos/parâmetros da Classe Mamiferos que serão usados para inicializar os atributos do objeto.
        self.nome_popular = nome_popular  # Atribui o valor do parâmetro nome_popular ao atributo nome_popular da instância.
        self.idade = idade  # Atribui o valor do parâmetro idade ao atributo idade da instância.
        self.cor = cor  # Atribui o valor do parâmetro cor ao atributo cor da instância.
   
    def mamar(self):  # Define um método chamado mamar, que descreve um comportamento que os objetos da classe podem realizar.
        return "mamando ..."  # Retorna a string "mamando ...", que descreve a ação de mamar.

    def chorar(self):  # Define um método chamado chorar, que representa uma ação que o mamífero pode realizar.
        return "chorando ..."  # Retorna a string "chorando ...", que descreve a ação de chorar.

# %%
# Definindo a classe Mamifero

class Mamifero:
    # O método __init__ é o construtor da classe, chamado quando criamos um novo objeto
    def __init__(self, nome_popular, idade, cor):
        self.nome_popular = nome_popular  # Atributo nome_popular recebe o valor passado ao criar o objeto
        self.idade = idade  # Atributo idade recebe o valor passado ao criar o objeto
        self.cor = cor  # Atributo cor recebe o valor passado ao criar o objeto

    # Método mamar que retorna uma string
    def mamar(self):
        return "mamando ..."

    # Método chorar que retorna uma string
    def chorar(self):
        return "chorando ..."

# Criando o objeto, que é uma instância de uma classe.
objeto = Mamifero(nome_popular="Ornitorrinco", idade=17, cor="Caramelo")

# Acessando e imprimindo os atributos do objeto
print(objeto.nome_popular)  # Saída: Ornitorrinco
print(objeto.idade)  # Saída: 17
print(objeto.cor)  # Saída: Caramelo

# Chamando os métodos do objeto
print(objeto.mamar())  # Saída: mamando ...
print(objeto.chorar())  # Saída: chorando ...
# Out:
# Ornitorrinco
# 17
# Caramelo
# mamando ...
# chorando ...

# %%
# Chamando o método chorar do objeto
objeto.chorar()

# Quando você cria o objeto objeto da classe Mamifero, o método __init__ é chamado com os parâmetros fornecidos.
# O objeto objeto agora possui os atributos nome_popular, idade e cor.

# Quando você chama objeto.chorar(), o Python procura o método chorar na classe Mamifero.
# O método chorar é encontrado e executado.
# O método chorar retorna a string "chorando ...".
# A string "chorando ..." é o resultado da chamada do método objeto.chorar().
# Out:
# 'chorando ...'

# %%
# 1. Definindo uma Classe
class Pessoa:
    pass  # 'pass' é usado para indicar que a classe está vazia, mas você pode adicionar membros posteriormente


# 2. Método __init__
class Carro:
    def __init__(self, modelo, ano):
        self.modelo = modelo
        self.ano = ano


# 3. Métodos em uma Classe
class Cachorro:
    def latir(self):
        return "Woof!"


# 4. Atributos de Instância
class Aluno:
    def __init__(self, nome, idade):
        self.nome = nome
        self.idade = idade


# 5. Utilizando a Referência 'self'
class Circulo:
    pi = 3.14  # Atributo de Classe

    def __init__(self, raio):
        self.raio = raio  # Atributo de Instância

    def calcular_area(self):
        return self.pi * (self.raio ** 2)


# Exemplos de Uso
if __name__ == "__main__":
    # 1. Definindo uma Classe
    pessoa = Pessoa()

    # 2. Método __init__
    carro = Carro(modelo="Civic", ano=2022)

    # 3. Métodos em uma Classe
    cachorro = Cachorro()
    print(cachorro.latir())

    # 4. Atributos de Instância
    aluno = Aluno(nome="Maria", idade=25)
    print(f"Nome: {aluno.nome}, Idade: {aluno.idade}")

    # 5. Utilizando a Referência 'self'
    circulo = Circulo(raio=5)
    area = circulo.calcular_area()
    print(f"Área do círculo: {area}")
# Out:
# Woof!
# Nome: Maria, Idade: 25
# Área do círculo: 78.5

# %% [markdown]
# ### Retornando ao dataset aluguel.csv

# %% [markdown]
# Qual a diferença entre Series e DataFrames?
#
# - Series é um objeto array unidimensional
# - Dataframe é uma matriz bidimensional rotulada, ou seja, para a qual podem ser atribuídos rótulos (nomes)  aos seus atributos (colunas) e indices númericos às suas linhas.

# %%
# vamos transformar em dataframe usando um [] e um método para ordenar
df.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
# Out:
#                                      Valor
# Tipo
# Quitinete                      1246.840909
# Pousada/Chalé                  1480.000000
# Casa de Vila                   1574.369478
# Box/Garagem                    1899.756098
# Studio                         2400.000000
# Loft                           2557.882353
# Flat                           4546.189076
# Apartamento                    4744.614648
# Chácara                        4900.000000
# Casa                           6793.454922
# Loja Shopping/ Ct Comercial    8126.178862
# Casa de Condomínio            11952.061245
# Sítio                         12499.000000
# Loja/Salão                    13769.646770
# Casa Comercial                14478.264151
# Conjunto Comercial/Sala       14715.045521
# Loteamento/Condomínio         22000.000000
# Hotel                         25000.000000
# Terreno Padrão                32567.714286
# Galpão/Depósito/Armazém       53407.062600
# Indústria                    120000.000000
# ...

# %%
# Importa a biblioteca pandas e define o alias 'pd'
import pandas as pd

# %%
# A função pd.read_csv(url) lê o arquivo CSV e transforma-o em um DataFrame
url = "dataset/aluguel.csv"
pd.read_csv(url)
# Out:
#       Tipo;Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0              Quitinete;Copacabana;1;0;0;40;1700;500;60
# 1                  Casa;Jardim Botânico;2;0;1;100;7000;;
# 2      Conjunto Comercial/Sala;Barra da Tijuca;0;4;0;...
# 3                 Apartamento;Centro;1;0;0;15;800;390;20
# 4             Apartamento;Higienópolis;1;0;0;48;800;230;
# ...                                                  ...
# 32955               Quitinete;Centro;0;0;0;27;800;350;25
# 32956       Apartamento;Jacarepaguá;3;1;2;78;1800;800;40
# 32957  Apartamento;São Francisco Xavier;2;1;0;48;1400...
# 32958              Apartamento;Leblon;2;0;0;70;3000;760;
# 32959  Conjunto Comercial/Sala;Centro;0;0;0;250;6500;...
#
# [32960 rows x 1 columns]

# %%
# Exibindo o conteúdo do DataFrame 'dados'
df = pd.read_csv(url)

# %%
dados = pd.read_csv(url,sep=";")

# %%
# Considere uma lista de anos de lançamento de um imóvel. Insira os valores em Series

lancamentos = pd.Series([2024,2025,2026,2027])
lancamentos
# Out:
# 0    2024
# 1    2025
# 2    2026
# 3    2027
# dtype: int64

# %%
# Exercício - Crie series com dicionário

lancamentos = pd.Series({'jan':2024,'fev':2025,'mar':2026,'abr':2027})
lancamentos
# Out:
# jan    2024
# fev    2025
# mar    2026
# abr    2027
# dtype: int64

# %%
# Mostre 23 registros no cabeçalho
df.head(23)
# Out:
#    Tipo;Bairro;Quartos;Vagas;Suites;Area;Valor;Condominio;IPTU
# 0           Quitinete;Copacabana;1;0;0;40;1700;500;60
# 1               Casa;Jardim Botânico;2;0;1;100;7000;;
# 2   Conjunto Comercial/Sala;Barra da Tijuca;0;4;0;...
# 3              Apartamento;Centro;1;0;0;15;800;390;20
# 4          Apartamento;Higienópolis;1;0;0;48;800;230;
# 5            Apartamento;Vista Alegre;3;1;0;70;1200;;
# 6           Apartamento;Cachambi;2;0;0;50;1300;301;17
# 7   Casa de Condomínio;Barra da Tijuca;5;4;5;750;2...
# 8            Casa de Condomínio;Ramos;2;2;0;65;1000;;
# 9   Conjunto Comercial/Sala;Centro;0;3;0;695;35000...
# 10                 Apartamento;Centro;1;0;0;36;1200;;
# 11            Apartamento;Grajaú;2;1;0;70;1500;642;74
# 12  Apartamento;Lins de Vasconcelos;3;1;1;90;1500;...
# 13        Apartamento;Copacabana;1;0;1;40;2000;561;50
# 14            Quitinete;Copacabana;1;0;0;27;1800;501;
# 15    Apartamento;Copacabana;4;3;1;243;13000;2000;803
# ...

# %%
# Mostre o final do DataFrame
df.tail()

# %%
# Exercício - Como examinar a quantidade de linhas do dataframe?
# antes vamos ver o tipo

df.dtypes
# Out:
# Quartos       float64
# Vagas         float64
# Suites        float64
# Area          float64
# Valor         float64
# Condominio    float64
# IPTU          float64
# dtype: object

# %%
# Verificando as colunas do Dataframe
print(df.columns) # Exibe Index(['Quartos', 'Vagas', 'Suites', 'Area', 'Valor', 'Condominio', 'IPTU'], dtype='object')
# Out:
# Index(['Quartos', 'Vagas', 'Suites', 'Area', 'Valor', 'Condominio', 'IPTU'], dtype='object')

# %%
# vamos ver quantidade de linhas do dataframe
len(df)
# Out:
# 32960

# %%
print(df.columns)
# Out:
# Index(['Quartos', 'Vagas', 'Suites', 'Area', 'Valor', 'Condominio', 'IPTU'], dtype='object')

# %%
# Acesse apenas a coluna Tipo
dados['Tipo']
# Out:
# 0                      Quitinete
# 1                           Casa
# 2        Conjunto Comercial/Sala
# 3                    Apartamento
# 4                    Apartamento
#                   ...
# 32955                  Quitinete
# 32956                Apartamento
# 32957                Apartamento
# 32958                Apartamento
# 32959    Conjunto Comercial/Sala
# Name: Tipo, Length: 32960, dtype: object

# %% [markdown]
# ### Trelo Fundamentos Panda -> Tarefa : Análise exploratório dos dados : Calcular valores médios de aluguel por tipo de imóvel
#
#
# - Quais são os valores médios de alguel por tipo de imóvel?
#
#     - A tarefa será calcular os valores médios de aluguel por tipo de imóvel usando os dados do dataset aluguel.csv. A análise será feita utilizando a biblioteca pandas para manipulação e agregação dos dados.

# %%
# O comando abaixo calcula a média dos valores na coluna 'Valor' do DataFrame 'dados'.
# 'dados' é um DataFrame do pandas que contém os dados do arquivo aluguel.csv.
# 'dados['Valor']' seleciona a coluna 'Valor' do DataFrame e foi definido no comando 'dados = pd.read_csv(url,sep=";")'
# '.mean()' calcula a média dos valores dessa coluna.

dados['Valor'].mean()
# Out:
# np.float64(12952.659715265761)

# %% [markdown]
# *`O retorno é uma Series`*
#
# - O método groupby do Pandas permite agrupar e resumir dados de um DataFrame, com base em um ou mais critérios. Esses critérios podem ser variáveis numéricas ou categóricas, como colunas ou índices do DataFrame.
#
# - A ideia por trás do groupby é dividir os dados em grupos com base nos critérios selecionados e, em seguida, aplicar uma operação a esses grupos. Essa operação pode ser uma função de agregação, como soma, média, contagem, desvio padrão, entre outras, ou mesmo uma operação personalizada definida pela pessoa usuária.
#
# *Esse método possui diversos parâmetros, alguns deles são:*
#
#  - by: esse é o parâmetro mais comum e é usado para especificar a coluna ou colunas que queremos agrupar. Como argumento dele, podemos passar o nome de uma coluna ou uma lista de nomes de colunas;
#
# - axis: utilizamos esse parâmetro para especificar o eixo ao longo do qual queremos agrupar. O valor padrão dele é 0, o que significa que as linhas serão agrupadas. Se quisermos agrupar as colunas, devemos definir esse parâmetro como 1;
#
# - sort: esse parâmetro é um booleano (True ou False) que indica se os grupos devem ser ordenados pelo valor da coluna de agrupamento. O valor padrão é True;
#
# - dropna: utilizamos esse parâmetro para controlar se os valores ausentes (NaN) serão excluídos ou não durante o processo de agrupamento. O valor padrão é True.

# %%
# O comando abaixo agrupa os dados do DataFrame 'df' pela coluna 'Tipo' e seleciona a coluna 'Valor' de cada grupo.
# 'df' é um DataFrame do pandas que já foi agrupado pela coluna 'Tipo'.
# 'df.groupby('Tipo')['Valor']' seleciona a coluna 'Valor' de cada grupo no DataFrame 'df'.
# O resultado é atribuído à variável 'pesquisa_tipo'.

pesquisa_tipo = df.groupby('Tipo')['Valor']

# %%
# O comando abaixo agrupa os dados do DataFrame 'dados' pela coluna 'Tipo' e calcula a média de todas as colunas numéricas para cada grupo.
# 'dados' é um DataFrame do pandas que contém os dados do arquivo CSV.
# 'dados.groupby('Tipo')' agrupa os dados pela coluna 'Tipo'.
# '.mean(numeric_only=True)' calcula a média de todas as colunas numéricas para cada grupo.
# O resultado é atribuído à variável 'df' e exibido.

df = dados.groupby('Tipo').mean(numeric_only=True)
df
# Out:
#                                Quartos      Vagas     Suites          Area  \
# Tipo
# Apartamento                   2.481569   1.232388   0.875998    119.790498
# Box/Garagem                   0.060976   1.304878   0.000000     17.524390
# Casa                          3.133402   1.795243   1.258532    250.578077
# Casa Comercial                1.562264   2.203774   0.260377    372.241509
# Casa de Condomínio            4.007028   3.101406   2.864458    456.161647
# Casa de Vila                  1.927711   0.389558   0.228916     78.469880
# Chácara                       3.000000   0.000000   0.000000      0.000000
# Conjunto Comercial/Sala       0.040939   2.516801   0.010858    214.472487
# Flat                          1.415966   0.962185   0.754202     65.483193
# Galpão/Depósito/Armazém       0.043339   5.587480   0.000000   2514.810594
# Hotel                        25.500000   2.500000  12.000000    885.500000
# ...

# %% [markdown]
# ### `Matplotlib - Biblioteca para Gerar Gráficos`
#
# O **Matplotlib** é uma biblioteca em Python que usamos para criar diferentes tipos de gráficos. Ela é muito útil quando queremos visualizar nossos dados de maneira fácil e clara.

# %% [markdown]
# `Tipos de Gráficos`

# %%
# PIZZA
# Um gráfico que mostra as partes de um todo, como fatias de uma pizza, demonstrando a proporção de diferentes categorias em um conjunto de dados.

# matplotlib.pyplot é um submódulo específico dentro do matplotlib que fornece uma interface simplificada para criar gráficos.
# A interface pyplot é projetada para ser semelhante à interface de plotagem do MATLAB, oferecendo uma maneira simples e fácil de criar gráficos de maneira interativa e scriptável.
# pyplot contém funções que permitem criar figuras, adicionar rótulos, títulos, legendas, e muito mais com comandos simples.
# Se você importasse apenas matplotlib, você teria que acessar as funções de plotagem de uma maneira mais indireta e complexa

import matplotlib.pyplot as plt


# Define as categorias que serão mostradas no gráfico de pizza.
# 'labels' são os rótulos das fatias do gráfico.
labels = ['Maçã', 'Banana', 'Laranja', 'Uva']

# Define os tamanhos de cada fatia do gráfico, correspondendo às categorias acima.
# 'sizes' são as proporções de cada categoria.
sizes = [20, 30, 25, 25]

# Cria um gráfico de pizza.
# 'sizes' especifica o tamanho de cada fatia.
# 'labels' especifica os rótulos das fatias.
# 'autopct' define o formato de exibição das porcentagens nas fatias.
plt.pie(sizes, labels=labels, autopct='%1.1f%%')

# Define o título do gráfico.
plt.title('Distribuição de Frutas')

# Exibe o gráfico de pizza.
plt.show()

# %%
# HISTOGRAMA
# Um gráfico de barras que mostra a distribuição de dados em intervalos. Útil para ver como os dados estão distribuídos em diferentes intervalos.

import matplotlib.pyplot as plt  # Importa a biblioteca matplotlib para criar gráficos

# Dados de exemplo para criar o histograma
data = [1, 2, 2, 3, 3, 3, 4, 4, 4, 4]

# Cria o histograma
# 'data' são os dados que serão plotados no histograma
# 'bins=4' define o número de intervalos (barras) no histograma
# 'edgecolor='black'' define a cor das bordas das barras como preta
plt.hist(data, bins=4, edgecolor='black')

# Define o título do gráfico
plt.title('Histograma')

# Define o rótulo do eixo X
plt.xlabel('Valores')

# Define o rótulo do eixo Y
plt.ylabel('Frequência')

# Mostra o gráfico na tela
plt.show()

# %%
# BARRAS
# Um gráfico que usa barras para mostrar a quantidade de diferentes categorias. Comparar quantidades entre diferentes categorias.

# Importa a biblioteca matplotlib para criar gráficos
import matplotlib.pyplot as plt  

# Define as categorias para o gráfico de barras
categorias = ['A', 'B', 'C', 'D']  

# Define os valores correspondentes a cada categoria
valores = [5, 7, 2, 4]  

# Cria o gráfico de barras
# 'categorias' são os rótulos das barras
# 'valores' são as alturas das barras
# 'color' define a cor de cada barra
plt.bar(categorias, valores, color=['red', 'blue', 'green', 'purple'])

# Define o título do gráfico
plt.title('Gráfico de Barras')  

# Define o rótulo do eixo X
plt.xlabel('Categorias')  

# Define o rótulo do eixo Y
plt.ylabel('Valores')  

# Mostra o gráfico na tela
plt.show()

# %%
# LINHAS
# Um gráfico que usa linhas para conectar pontos de dados. Mostra a mudança de valores ao longo do tempo ou outra sequência.

# Importa a biblioteca matplotlib para criar gráficos
import matplotlib.pyplot as plt  

# Define os valores para o eixo X
x = [1, 2, 3, 4, 5]  

# Define os valores para o eixo Y
y = [2, 3, 5, 7, 11]  

# Cria o gráfico de linhas usando os valores de 'x' e 'y'
# 'marker='o'' adiciona um marcador circular para cada ponto de dados na linha
plt.plot(x, y, marker='o')  

# Adiciona o título ao gráfico
plt.title('Gráfico de Linhas')  

# Adiciona o rótulo ao eixo X
plt.xlabel('X')  

# Adiciona o rótulo ao eixo Y
plt.ylabel('Y')  

# Exibe o gráfico na tela
plt.show()

# %%
# DISPERSÃO
# Um gráfico que usa pontos para representar valores individuais, monstrando a relação entre duas variáveis.

import matplotlib.pyplot as plt

# Define os valores para o eixo X
x = [1, 2, 3, 4, 5]

# Define os valores para o eixo Y
y = [2, 4, 1, 3, 5]

# Cria o gráfico de dispersão (scatter plot) usando os valores de 'x' e 'y'
# 'color='red'' define a cor dos pontos como vermelha
plt.scatter(x, y, color='red')

# Adiciona o título ao gráfico
plt.title('Gráfico de Dispersão')

# Adiciona o rótulo ao eixo X
plt.xlabel('X')

# Adiciona o rótulo ao eixo Y
plt.ylabel('Y')

# Exibe o gráfico na tela
plt.show()

# %%
# O comando abaixo usa o 'pip', que é o gerenciador de pacotes do Python, para instalar a biblioteca 'matplotlib'.
# A biblioteca 'matplotlib' é usada para criar visualizações gráficas, como gráficos de linha, gráficos de barras, gráficos de dispersão, etc.
# O ponto de exclamação '!' é usado em ambientes de notebook como Jupyter para executar comandos do sistema.

# !pip install matplotlib

# %%
# O comando abaixo agrupa os dados do DataFrame 'df' pela coluna 'Tipo' e seleciona a coluna 'Valor' de cada grupo.
# Em seguida, calcula a média dos valores para cada tipo.
# O resultado é um DataFrame onde cada linha representa um tipo de imóvel e a média do valor correspondente.
# A função 'sort_values('Valor')' ordena o DataFrame resultante com base na coluna 'Valor', do menor para o maior valor médio.

df.groupby('Tipo')[['Valor']].mean().sort_values('Valor')
# Out:
#                                      Valor
# Tipo
# Quitinete                      1246.840909
# Pousada/Chalé                  1480.000000
# Casa de Vila                   1574.369478
# Box/Garagem                    1899.756098
# Studio                         2400.000000
# Loft                           2557.882353
# Flat                           4546.189076
# Apartamento                    4744.614648
# Chácara                        4900.000000
# Casa                           6793.454922
# Loja Shopping/ Ct Comercial    8126.178862
# Casa de Condomínio            11952.061245
# Sítio                         12499.000000
# Loja/Salão                    13769.646770
# Casa Comercial                14478.264151
# Conjunto Comercial/Sala       14715.045521
# Loteamento/Condomínio         22000.000000
# Hotel                         25000.000000
# Terreno Padrão                32567.714286
# Galpão/Depósito/Armazém       53407.062600
# Indústria                    120000.000000
# ...

# %%
# Agrupando os dados por 'Tipo' e calculando a média dos valores na coluna 'Valor'
df_valor_tipo = df.groupby('Tipo')[['Valor']].mean().sort_values('Valor')

# Agora df_valor_tipo contém um DataFrame onde cada linha representa um tipo de imóvel
# A coluna 'Valor' contém a média dos valores para aquele tipo de imóvel.

# %%
# Vamos plotar um gráfico - crie uma variável para receber o dataframe

df_preco_tipo = df.groupby('Tipo')[['Valor']].mean().sort_values('Valor')

# Vou plotar agora...

df_preco_tipo.plot(kind='barh',figsize=(14,10),color='purple')

# Eixo X a média de alguel
# Eixo Y o tipo de imóvel

# Este gráfico é útil para visualizar e comparar rapidamente os valores médios de aluguel para diferentes tipos de imóveis.
# Ele pode ajudar a identificar quais tipos de imóveis são mais caros e quais são mais acessíveis, auxiliando na tomada de decisões para investimentos, aluguéis ou outras análises financeiras.
# Out:
# <Axes: ylabel='Tipo'>

# %% [markdown]
# #### Remover os imóveis comerciais

# %%
# Fazendo a query

dados.query("@imoveis_comerciais in Tipo")
# Out:
#                           Tipo           Bairro  Quartos  Vagas  Suites  Area  \
# 2      Conjunto Comercial/Sala  Barra da Tijuca        0      4       0   150
# 9      Conjunto Comercial/Sala           Centro        0      3       0   695
# 16              Prédio Inteiro         Botafogo        0      0       0   536
# 26     Conjunto Comercial/Sala    São Cristóvão        0      1       0    25
# 29                  Loja/Salão     Campo Grande        0      1       0    35
# ...                        ...              ...      ...    ...     ...   ...
# 32942  Conjunto Comercial/Sala  Barra da Tijuca        0      1       0    55
# 32946  Conjunto Comercial/Sala           Centro        0      0       0   140
# 32948  Conjunto Comercial/Sala           Centro        0      0       0    32
# 32954              Box/Garagem           Centro        0      0       0   755
# 32959  Conjunto Comercial/Sala           Centro        0      0       0   250
#
# ...

# %%
imoveis_comerciais = ['Conjunto Comercial/Sala', 
                      'Prédio Inteiro', 'Loja/Salão', 
                      'Galpão/Depósito/Armazém', 
                      'Casa Comercial', 'Terreno Padrão',
                      'Loja Shopping/ Ct Comercial',
                      'Box/Garagem', 'Chácara',
                      'Loteamento/Condomínio', 'Sítio',
                      'Pousada/Chalé', 'Hotel', 'Indústria']

# %%
dados.query("@imoveis_comerciais not in Tipo")
# Out:
#               Tipo                Bairro  Quartos  Vagas  Suites  Area  \
# 0        Quitinete            Copacabana        1      0       0    40
# 1             Casa       Jardim Botânico        2      0       1   100
# 3      Apartamento                Centro        1      0       0    15
# 4      Apartamento          Higienópolis        1      0       0    48
# 5      Apartamento          Vista Alegre        3      1       0    70
# ...            ...                   ...      ...    ...     ...   ...
# 32953  Apartamento                 Méier        2      0       0    70
# 32955    Quitinete                Centro        0      0       0    27
# 32956  Apartamento           Jacarepaguá        3      1       2    78
# 32957  Apartamento  São Francisco Xavier        2      1       0    48
# 32958  Apartamento                Leblon        2      0       0    70
#
#         Valor  Condominio  IPTU
# 0      1700.0       500.0  60.0
# 1      7000.0         NaN   NaN
# ...

# %%
# vamos salvar em uma variável

df = dados.query("@imoveis_comerciais not in Tipo")
df.head()
# Out:
#           Tipo           Bairro  Quartos  Vagas  Suites  Area   Valor  \
# 0    Quitinete       Copacabana        1      0       0    40  1700.0
# 1         Casa  Jardim Botânico        2      0       1   100  7000.0
# 3  Apartamento           Centro        1      0       0    15   800.0
# 4  Apartamento     Higienópolis        1      0       0    48   800.0
# 5  Apartamento     Vista Alegre        3      1       0    70  1200.0
#
#    Condominio  IPTU
# 0       500.0  60.0
# 1         NaN   NaN
# 3       390.0  20.0
# 4       230.0   NaN
# 5         NaN   NaN

# %%
df.Tipo.unique()
# Out:
# array(['Quitinete', 'Casa', 'Apartamento', 'Casa de Condomínio', 'Flat',
#        'Casa de Vila', 'Loft', 'Studio'], dtype=object)

# %%
# Vamos plotar um gráfico - crie uma variável para receber o dataframe

# Vamos plotar um gráfico - crie uma variável para receber o dataframe

df_preco_tipo = df.groupby('Tipo')[['Valor']].mean().sort_values('Valor')

# Vou plotar agora...

df_preco_tipo.plot(kind='barh',figsize=(14,10),color='purple')
# Out:
# <Axes: ylabel='Tipo'>
