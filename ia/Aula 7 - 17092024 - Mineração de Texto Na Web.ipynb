# %% [markdown]
# ### **SENAI-DF - Python : Artificial Intelligence - Vespertino - QUA.494.002 - 17/09/2024**
# ### Aula 07 - Mineraçao de Texto em Artigos da Internet

# %% [markdown]
# ### Ambientação (mineração de texto em artigos da internet)
#
# A **mineração de texto** em artigos da internet é uma técnica de **Processamento de Linguagem Natural (PLN)** e **Web Scraping** utilizada para **extrair, processar e analisar** grandes volumes de dados textuais disponíveis em sites, blogs, notícias e outros tipos de páginas web.
#
# ## O que envolve?
#
# ### 1. Web Scraping
# - **Definição**: Web scraping é o processo automatizado de coleta de informações da web. Usamos scripts ou bibliotecas (como BeautifulSoup, Scrapy ou Selenium) para "raspar" dados de sites, como artigos de notícias, blogs e outros textos de interesse.
# - **Objetivo**: Obter o conteúdo textual de uma página da web, que é a base da mineração de texto. O scraping coleta as palavras que estarão disponíveis para análise.
#
# ### 2. Mineração de Texto
# - **Definição**: Mineração de texto é a análise de dados textuais, que busca padrões, palavras-chave, sentimentos e outros insights a partir de grandes volumes de texto.
# - **Objetivo**: Extrair informações úteis dos textos coletados, como tópicos principais, frequência de palavras, sentimentos expressos, etc.
# - **Técnicas Comuns**:
#   - **Tokenização**: Dividir o texto em palavras ou frases.
#   - **Contagem de palavras**: Identificar quais palavras aparecem com maior frequência.
#   - **Extração de tópicos**: Determinar os temas ou assuntos predominantes no texto.
#
# ### 3. Processamento de Linguagem Natural (PLN)
# - **Definição**: O PLN é uma área da Inteligência Artificial que busca entender e interpretar o conteúdo de textos humanos, ajudando as máquinas a processarem a linguagem natural.
# - **Objetivo**: Utilizar ferramentas e bibliotecas como NLTK, SpaCy e Transformers para fazer análises mais avançadas, como reconhecimento de entidades (nomes de pessoas, lugares), análise de sentimentos, e categorização de documentos.
#
# ## O que você pode aprender na mineração de texto de artigos na internet?
#
# - **Raspagem de dados textuais**: Coletar artigos de notícias ou blogs automaticamente.
# - **Análise de conteúdo**: Extrair as informações mais importantes de um artigo (como título, autor, data de publicação).
# - **Análise de sentimentos**: Descobrir se o tom do artigo é positivo, negativo ou neutro.
# - **Extração de tópicos**: Identificar os principais temas discutidos em diversos artigos.
#
# ## Por que isso é útil?
#
# Empresas, jornalistas, pesquisadores e desenvolvedores utilizam mineração de texto em artigos da internet para:
# - **Monitorar notícias**: Descobrir rapidamente quais são os tópicos mais discutidos.
# - **Análise de tendências**: Identificar tendências emergentes em diferentes indústrias.
# - **Pesquisa de mercado**: Analisar opiniões de clientes ou consumidores a partir de comentários e avaliações.
# - **Criação de conteúdo automatizado**: Usar os dados coletados para gerar relatórios ou artigos automaticamente.
#
# ## Ferramentas Comuns:
# - **BeautifulSoup** e **Scrapy** para web scraping.
# - **NLTK**, **SpaCy** e **Gensim** para processamento e análise de texto.

# %% [markdown]
# ### Uso da Biblioteca **Goose8**
#
# 1. **Instalação**: O processo de instalação da biblioteca **Goose** com o comando `pip install goose3`.
# 2. **Importação**: Mostra como importar a biblioteca **Goose** no seu projeto Python.
# 3. **Objeto Goose**: Introduz o objeto principal da biblioteca, que é responsável por gerenciar a extração de conteúdo.
# 4. **URL**: Explica como extrair informações de uma URL específica utilizando o objeto **Goose**, como o título e o corpo do texto do artigo.

# %% [markdown]
# ### 1. Instalação
#
# Para utilizar a biblioteca **Goose**, você precisa instalá-la primeiro. Goose é uma ferramenta poderosa de extração de conteúdo de artigos da web, como o título, o corpo do artigo, imagens e muito mais.

# %%
# Comando de instalação:
# !pip install goose3
# Out:
# ...
#      ---------------------------------------- 0.0/981.5 kB ? eta -:--:--
#      -------------------------------------- 981.5/981.5 kB 9.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for langdetect: filename=langdetect-1.0.9-py3-none-any.whl size=993251 sha256=9cbd02c3691e0ff72a521ceb6950b44a6d0915f9f76bddbdcc5e85c5971d3d1e
#   Stored in directory: c:\users\marcelo avelino\appdata\local\pip\cache\wheels\c1\67\88\e844b5b022812e15a52e4eaa38a1e709e99f06f6639d7e3ba7
# Successfully built langdetect
# ...

# %% [markdown]
# ## 2. Importação
#
# Após instalar a biblioteca Goose, você deve importá-la em seu projeto Python para começar a utilizá-la.

# %%
# Importamos a classe Goose da biblioteca goose3 que é utilizada para extrair conteúdo de artigos da web, como o título, corpo do texto, imagens e metadados.
from goose3 import Goose

# %% [markdown]
# ## 3. Objeto Goose
#
# O objeto *Goose* é a base da biblioteca. Ele é utilizado para inicializar e configurar o processo de extração de conteúdo. A partir dele, você pode extrair informações de URLs específicas, como títulos, imagens e o corpo do artigo.

# %%
# Inicializamos o objeto Goose que será usado para realizar a extração de conteúdo de URLs de artigos da web.
g = Goose()

# %% [markdown]
# ## 4. URL
#
# Com o objeto *Goose* inicializado, você pode passar uma URL para ele, e ele retornará um objeto com várias informações extraídas automaticamente do site. Essas informações podem incluir o título, o corpo do texto, imagens principais, e outros metadados.
#
# ## Exemplo de Extração de Conteúdo de uma URL
#
# # Defina a URL de onde o conteúdo será extraído
# url = 'https://www.exemplo.com/artigo'
#
# # Usamos o objeto Goose para extrair conteúdo da URL
# article = g.extract(url=url)
#
# # Exibe o título e o corpo do artigo extraído
# print("Título:", article.title)
# print("Conteúdo:", article.cleaned_text)
#
# # O que está acontecendo aqui:
#
# - **g.extract(url=url)**: Extrai o conteúdo da URL passada.
# - **article.title**: Retorna o título do artigo.
# - **article.cleaned_text**: Retorna o corpo do artigo, já limpo de elementos HTML.

# %%
# Importamos a biblioteca NLTK (Natural Language Toolkit) que é uma biblioteca poderosa para trabalhar com Processamento de Linguagem Natural (PLN).
import nltk

# Fazemos o download do tokenizer 'punkt' que é responsável por dividir o texto em sentenças ou palavras.
# O 'punkt' é necessário para realizar a tokenização de textos, que é uma técnica básica de mineração de texto.
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Marcelo
# [nltk_data]     Avelino\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Criamos um objeto utilizando o construtor de uma classe.
# O construtor é um método especial que inicializa o objeto.
# No exemplo abaixo, "Construtor" representa uma classe, e "objeto" é a instância criada a partir dessa classe.

# objeto = Construtor()

# %%
class Usuario():
    # Método construtor
    # O método __init__ é o construtor da classe. Ele é chamado automaticamente sempre que criamos um novo objeto da classe Usuario.
    def __init__(self, nome, nick_name, senha, email):
        # Atributos da classe Usuario
        # Cada novo objeto Usuario terá os atributos 'nome', 'nick_name', 'senha' e 'email'.
        # 'self' refere-se ao objeto atual que está sendo criado.
        self.nome = nome           # Armazena o nome do usuário
        self.nick_name = nick_name # Armazena o apelido do usuário
        self.senha = senha         # Armazena a senha do usuário
        self.email = email         # Armazena o email do usuário

# %%
# Definimos a variável 'url' para armazenar o endereço do site desejado. Neste caso, a URL aponta para o site do Diário Oficial do Distrito Federal (DODF).
url = "https://www.dodf.df.gov.br/"

# %% [markdown]
# ## Fase de Extração
#
# Nesta fase, estamos interessados em **extrair** dados de uma página da web, utilizando técnicas de **Web Scraping** e acessando propriedades específicas do conteúdo da página, como o título, texto, data e meta-tags HTML.
#
# ## 1. Extract(url)
#
# A função `extract(url)` é usada para extrair conteúdo de uma URL específica. Essa função pertence à biblioteca de extração de conteúdo (como o Goose), que coleta o título, texto e outras informações relevantes de uma página da web.
#
# ## 2. Utilizar Propriedades (title, texto, data, meta-tags html)
#
# Após a extração do conteúdo da página, podemos acessar diferentes propriedades do artigo, como o título, o texto principal, a data de publicação e meta-tags HTML.
#
# ## 3. Web Scraping
#
# Web Scraping é o processo de raspar informações de páginas da web. Ele permite coletar grandes volumes de dados textuais de maneira automatizada, para que possamos processá-los e analisá-los posteriormente.
#
# Ferramentas Comuns: BeautifulSoup, Scrapy, Selenium e Goose são ferramentas populares para realizar web scraping.
#
# O Que Extraímos: Podemos extrair informações como textos, títulos, imagens, datas e outros elementos HTML importantes para a análise de dados.
#
# ## 4. Direitos Autorais
#
# Ao realizar Web Scraping, é importante considerar os direitos autorais do conteúdo extraído.
#
# Respeitar os Termos de Serviço: Verifique se o site permite scraping, observando seus termos de uso e políticas de privacidade. Alguns sites possuem restrições claras sobre a extração de dados.
#
# Uso Justo: Em alguns casos, o uso justo de conteúdo é permitido para fins educacionais ou de pesquisa, mas é necessário dar os devidos créditos ao criador do conteúdo.
#
# Considerações Legais: Sempre respeite as leis locais e internacionais relacionadas à propriedade intelectual e à coleta de dados.

# %%
### 1. Extract(url)
artigo = g.extract(url)

# g.extract(url=url): Extrai o conteúdo da URL passada.
# artigo: O objeto retornado contém várias propriedades úteis como o título, o corpo do artigo, a data de publicação e outras informações.

# %%
# A propriedade 'domain' retorna o domínio do site de onde o artigo foi extraído.
# Isso pode ser útil para saber de qual site o conteúdo foi obtido, especialmente quando estamos trabalhando com múltiplas fontes.

print("Domínio:", artigo.domain)

# ou apenas:

artigo.domain
# Out:
# Domínio: www.dodf.df.gov.br
# 'www.dodf.df.gov.br'

# %%
# A propriedade 'meta_encoding' retorna a codificação de caracteres da página da web.
# Essa propriedade retorna a codificação de caracteres utilizada na página web (como UTF-8, ISO-8859-1, etc.), que é essencial para garantir que o conteúdo seja interpretado corretamente, especialmente em idiomas com caracteres especiais.
# Saber a codificação é importante ao lidar com conteúdo que pode conter diferentes tipos de caracteres e acentuações.
print("Codificação:", artigo.meta_encoding)

## ou apenas:

artigo.meta_encoding
# Out:
# Codificação: UTF-8
# 'UTF-8'

# %%
# O comando 'print(type(artigo))' exibe o tipo de objeto que a variável 'artigo' representa.
# Isso é útil para verificar a classe do objeto e entender melhor sua estrutura.
# Por exemplo, ele pode mostrar se o objeto é da classe GooseArticle, ou de outra classe relevante, o que ajuda a entender como manipular o objeto no código.
print(type(artigo))
# Out:
# <class 'goose3.article.Article'>

# %%
# A propriedade 'publish_date' retorna a data de publicação do artigo, se estiver disponível no conteúdo extraído.
# Isso é útil para saber quando o artigo foi publicado, especialmente em sites de notícias ou blogs.
# Se a data não estiver disponível no HTML, essa propriedade pode retornar None ou uma data inválida.
print("Data de publicação:", artigo.publish_date)
# Out:
# Data de publicação: None

# %%
# A propriedade 'title' retorna o título do artigo extraído da URL.
# O título é geralmente encontrado na tag <title> ou em outra tag relevante (como <h1>) no HTML da página.
# Usar o título é importante para identificar o conteúdo do artigo de forma resumida e clara.
print("Título do artigo:", artigo.title)
# Out:
# Título do artigo: DODFe - Sistema de busca no novo Diário Oficial do Distrito Federal

# %%
# Essa propriedade retorna a meta descrição da página web, que é uma breve descrição do conteúdo da página.
# Ela é geralmente usada nos resultados de busca de motores de pesquisa como Google e está contida nas meta tags HTML, dentro do elemento <meta name="description">.
# A meta descrição oferece um resumo rápido do conteúdo da página e pode ser útil para dar contexto sobre o artigo ou post.
print("Meta Descrição:", artigo.meta_description)
# Out:
# Meta Descrição:

# %%
# Essa propriedade retorna uma lista de todos os links (URLs) encontrados no artigo. Esses links são extraídos de elementos como <a href="..."> no HTML da página.
# Usar essa propriedade é útil para coletar referências ou identificar os sites e páginas que o artigo menciona ou referencia.
artigo.links
# Out:
# ['/js/modules/default/layouts/imagens/gabaritos/25c.pdf',
#  '/js/modules/default/layouts/imagens/gabaritos/25c.ai',
#  '/js/modules/default/layouts/imagens/gabaritos/25c.psd',
#  '/js/modules/default/layouts/imagens/gabaritos/25c.eps',
#  '/js/modules/default/layouts/imagens/gabaritos/50c.pdf',
#  '/js/modules/default/layouts/imagens/gabaritos/50c.ai',
#  '/js/modules/default/layouts/imagens/gabaritos/50c.psd',
#  '/js/modules/default/layouts/imagens/gabaritos/50c.eps',
#  '/js/modules/default/layouts/imagens/gabaritos/100c.pdf',
#  '/js/modules/default/layouts/imagens/gabaritos/100c.ai',
#  '/js/modules/default/layouts/imagens/gabaritos/100c.psd',
#  '/js/modules/default/layouts/imagens/gabaritos/100c.eps',
#  '/js/modules/default/layouts/imagens/gabaritos/50p.pdf',
#  '/js/modules/default/layouts/imagens/gabaritos/50p.ai',
#  '/js/modules/default/layouts/imagens/gabaritos/50p.psd',
#  '/js/modules/default/layouts/imagens/gabaritos/50p.eps',
# ...

# %%
# Essa propriedade retorna o texto principal do artigo, já limpo de elementos HTML, anúncios, menus e outros conteúdos irrelevantes.
# Isso deixa apenas o corpo do artigo de forma estruturada para análise ou leitura.
# Essa propriedade é extremamente útil quando se deseja obter apenas o conteúdo textual sem ruído, facilitando a análise de texto em tarefas de mineração de texto ou Processamento de Linguagem Natural (PLN).
print("Texto Limpo do Artigo:", artigo.cleaned_text)
# Out:
# Texto Limpo do Artigo: Abaixo são listados o(s) histórico(s) de pesquisa, caso queira você pode excluir clicando no botão exclusão.
#
# Abaixo são listadas a(s) pesquisa(s) macada como favorita, caso queira você pode excluir clicando no botão exclusão.
#
# Abaixo são listados em formato de diretório todos os diários lançados a partir de 1967, para selecionar basta escolher a pasta.
#
# Quanto custa publicar no DODF?
#
# De acordo com a Portaria Nº 30, de 09 de dezembro de 2020, a publicação de matérias no Diário Oficial do Distrito Federal teve novos valores fixados. Por tratar-se de atualização da métrica de cobrança, os contratos vigentes não serão alterados.
#
# As publicações em texto devem considerar a unidade de medida caractere e passam a custar:
#
# a) R$ 0,16 (dezesseis centavos) por caractere.
#
# As imagens devem ser enviadas ou entregues no formato “JPEG” ou “PNG”, mantendo a proporção definida conforme tabela abaixo, e passam a custar:
#
# ...

# %%
# Essa propriedade retorna uma lista de autores do artigo, se essa informação estiver disponível no conteúdo extraído.
# Os autores geralmente são identificados por meio de meta tags ou outros elementos específicos no HTML da página.
# Usar essa propriedade é útil para obter informações sobre quem escreveu ou colaborou na criação do artigo, o que pode ser relevante em análises de autoria ou pesquisa de credibilidade.
print("Autores do Artigo:", artigo.authors)
# Out:
# Autores do Artigo: []

# %% [markdown]
# ## **Desafio (Valendo o certificado)**
#
# 1. **Tokenização de palavras**: Dividimos o texto em palavras para poder analisá-las individualmente.
# 2. **Distribuição de frequências**: Calculamos a frequência de cada palavra, excluindo as **stopwords**, e visualizamos os resultados em um gráfico.
# 3. **WordCloud**: Geramos uma visualização da nuvem de palavras para destacar as palavras mais frequentes do artigo.
# 4. **Apresentação**: A última etapa é a apresentação dos resultados, que garante o recebimento do certificado.

# %%
# 1. Realizar a tokenização de palavras (do artigo)

# Comando para instalar a biblioteca NLTK (Natural Language Toolkit), que é essencial para o processamento da linguagem natural, que inclui funcionalidades como tokenização, análise de frequência e muito mais.
# !pip install nltk

# %%
# Importação de bibliotecas necessárias para extração de dados e análise de texto.

# 1 - NLTK (Natural Language Toolkit): Biblioteca poderosa para Processamento de Linguagem Natural (PLN),
# com ferramentas para tokenização, análise de frequência, stopwords, etc.
import nltk

# 2 - 'os': A biblioteca os do Python permite interação com o sistema operacional,
# fornecendo funções para manipulação de arquivos, pastas, e execução de comandos do sistema.
import os

# 3 - pyplot: Importamos 'pyplot' do matplotlib, uma biblioteca poderosa para criação de gráficos em Python,
# que fornece funções para criar gráficos de linha, barras, dispersão e muitos outros tipos de visualizações.
import matplotlib.pyplot as plt

# 4 - requests: Usada para realizar requisições HTTP para acessar páginas da web.
import requests

# 5 - BeautifulSoup: Utilizada para extrair e analisar o conteúdo HTML de páginas web.
from bs4 import BeautifulSoup

# 6 - word_tokenize: Função do NLTK para tokenizar o texto em palavras.
from nltk.tokenize import word_tokenize

# 7 - FreqDist: Ferramenta do NLTK para calcular a distribuição de frequências de palavras.
from nltk.probability import FreqDist

# 8 - stopwords: Conjunto de palavras comuns e irrelevantes, que são removidas do texto para análise mais eficiente.
from nltk.corpus import stopwords

# 9 - WordCloud: Biblioteca para gerar nuvens de palavras a partir de frequências de palavras.
from wordcloud import WordCloud
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[56], line 31
#      28 from nltk.corpus import stopwords
#      30 # 9 - WordCloud: Biblioteca para gerar nuvens de palavras a partir de frequências de palavras.
# ---> 31 from wordcloud import WordCloud
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
# A função 'word_tokenize' da biblioteca NLTK é importada. Essa função divide uma string em palavras ou tokens.
from nltk.tokenize import word_tokenize

# %%
# A função 'sent_tokenize' da biblioteca NLTK é importada. Essa função divide (tokeniza) um texto em sentenças.
from nltk.tokenize import sent_tokenize

# %%
# a classe 'FreqDist' da sub-biblioteca 'probability do NLTK' é importada para calcular a distribuição de frequencia de itens, como palavras em um texto, permitindo analisar quais palavras ou tokens aparecem com mais frequencia.
from nltk.probability import FreqDist

# %%
# Definimos a variável 'url' para armazenar o endereço do site desejado.
url = "https://www.dodf.df.gov.br/"

# %%
# Definição da Função 'plot_cloud': Cria e exibe uma nuvem de palavras (Word Cloud) utilizando a biblioteca matplotlib.

def plot_cloud(wordcloud): # Essa função exibe uma nuvem de palavras usando a biblioteca matplotlib.
    # Criar a Figura e define o tamanho da figura para a nuvem de palavras.
    plt.figure(figsize=(40, 30))
    
    # Exibe a imagem da nuvem de palavras
    plt.imshow(wordcloud)

    # Remover Eixos da imagem para que ela apareça de forma mais limpa, sem as bordas e eixos núméricos.
    plt.axis("off")

# %%
# A função 'word_tokenize' do NLTK tenta tokenizar a string fornecida (no caso, a URL).
# O parâmetro 'language' define o idioma em que a tokenização será feita (português neste caso).
# No entanto, a tokenização de uma URL pode não ser ideal, já que ela contém símbolos especiais.
nltk.word_tokenize(url, language='portuguese')

# %%
# A função 'sent_tokenize' do NLTK é usada para dividir o texto em sentenças.
# O argumento 'artigo' deve ser o texto extraído do artigo, como 'artigo.cleaned_text', e não o próprio objeto 'artigo'.
# A função retorna uma lista de sentenças extraídas do texto.
sentencas = nltk.sent_tokenize(artigo.cleaned_text)

# Exibe as primeiras 5 sentenças tokenizadas
print(sentencas[:5])

# %%
# Baixamos os recursos necessários do nltk para tokenização e stopwords
nltk.download('punkt')
nltk.download('stopwords')

# Função para extrair o texto de uma página web usando BeautifulSoup
def extrair_texto_da_pagina(url):
    # Fazemos uma requisição HTTP para a URL
    resposta = requests.get(url)
    
    # Usamos BeautifulSoup para analisar o conteúdo HTML da página
    soup = BeautifulSoup(resposta.content, 'html.parser')

    # Extraímos o texto bruto da página (ajuste conforme necessário)
    texto = soup.get_text()
    return texto

# URL do artigo no site DODF (substitua com a URL específica)
url = 'https://www.dodf.df.gov.br/'  # Substitua com a URL específica do artigo

# Extraímos o texto da página fornecida
texto = extrair_texto_da_pagina(url)

# Tokenizamos o texto em palavras e convertendo-as para minúsculas para uniformidade
tokens = word_tokenize(texto.lower())

# Carregamos as stopwords do NLTK para a língua portuguesa
stop_words = set(stopwords.words('portuguese'))

# Filtramos os tokens para remover stopwords e qualquer coisa que não seja uma palavra
filtered_tokens = [word for word in tokens if word not in stop_words and word.isalpha()]

# Criamos a distribuição de frequências das palavras filtradas
freq_dist = FreqDist(filtered_tokens)

# Exibimos as 10 palavras mais comuns no texto extraído
print(freq_dist.most_common(10))

# Plotamos a distribuição de frequências das 30 palavras mais comuns
plt.figure(figsize=(12, 6))
freq_dist.plot(30, cumulative=False)
plt.show()

# Geramos uma nuvem de palavras com base na distribuição de frequências
wordcloud = WordCloud(width=800, height=400, background_color='white').generate_from_frequencies(freq_dist)

# Plotamos a nuvem de palavras gerada
plt.figure(figsize=(10, 5))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')  # Removemos os eixos para uma visualização mais limpa
plt.show()

# %%
# Criamos uma nova figura com o tamanho 10x5 para exibir a nuvem de palavras
plt.figure(figsize=(10, 5))

# Exibimos a imagem da nuvem de palavras gerada
# 'imshow' exibe a imagem da WordCloud com interpolação 'bilinear' para suavizar a imagem
plt.imshow(wordcloud, interpolation='bilinear')

# Removemos os eixos da visualização para deixar a imagem mais limpa
plt.axis('off')

# Mostramos o gráfico com a nuvem de palavras
plt.show()

# %%
# Baixamos o pacote 'punkt' do NLTK, que é usado para a tokenização de textos.
# O 'punkt' contém modelos que permitem dividir um texto em palavras ou sentenças.
nltk.download('punkt')

# Baixamos o pacote 'stopwords' do NLTK, que contém listas de palavras irrelevantes (stopwords)
# em diferentes idiomas, como artigos, preposições, conjunções, etc. Essas palavras serão filtradas na análise.
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Marcelo
# [nltk_data]     Avelino\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to C:\Users\Marcelo
# [nltk_data]     Avelino\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
# Função para extrair o texto bruto de uma página web
def extrair_texto_da_pagina(url):
    # Faz uma requisição HTTP para a URL fornecida e retorna o conteúdo da página.
    resposta = requests.get(url)
    
    # Analisamos o conteúdo HTML da página usando BeautifulSoup
    # 'html.parser' é o analisador padrão que converte o conteúdo em um objeto BeautifulSoup
    soup = BeautifulSoup(resposta.content, 'html.parser')
    
    # Retornamos o texto bruto da página, removendo as tags HTML
    return soup.get_text()

# %%
# URL do artigo no site DODF
url = 'https://www.dodf.df.gov.br/'

# %%
# Extraímos o texto da página da web utilizando a função extrair_texto_da_pagina
# A variável 'url' deve conter o endereço da página que será processada
texto = extrair_texto_da_pagina(url)

# Tokenizamos o texto extraído, convertendo tudo para minúsculas para uniformidade
# O método 'word_tokenize' divide o texto em palavras (tokens)
tokens = word_tokenize(texto.lower())

# Carregamos as stopwords (palavras irrelevantes) em português utilizando o NLTK
# Stopwords são palavras como "de", "o", "a", que geralmente não são úteis para análise
stop_words = set(stopwords.words('portuguese'))

# Filtramos os tokens removendo as stopwords e palavras que não sejam alfabéticas
# O método 'word.isalpha()' garante que apenas palavras (sem números ou símbolos) sejam mantidas
filtered_tokens = [word for word in tokens if word not in stop_words and word.isalpha()]

# %%
# Calculamos a distribuição de frequência das palavras filtradas utilizando FreqDist.
# FreqDist é uma classe do NLTK que conta quantas vezes cada palavra aparece no texto.
freq_dist = FreqDist(filtered_tokens)

# Exibimos as 10 palavras mais comuns no texto, junto com suas frequências.
print(freq_dist.most_common(10))

# %%
# Criamos uma nova figura para o gráfico com o tamanho 12x6.
plt.figure(figsize=(12, 6))

# Plotamos a distribuição de frequência das 30 palavras mais comuns no texto.
# 'freq_dist.plot(30)' mostra as 30 palavras mais frequentes e suas respectivas contagens.
# 'cumulative=False' indica que queremos a frequência de cada palavra individualmente, e não de forma cumulativa.
freq_dist.plot(30, cumulative=False)

# Exibimos o gráfico gerado.
plt.show()

# %%
# Geramos uma nuvem de palavras a partir da distribuição de frequências calculada.
# Definimos o tamanho da imagem da nuvem de palavras como 3000x2000 pixels e a cor de fundo como preta.
# 'colormap' define o esquema de cores da nuvem de palavras, aqui estamos usando 'viridis' para um efeito visual.
wordcloud = WordCloud(width=3000, height=2000, background_color='black', colormap='viridis').generate_from_frequencies(freq_dist)

# Criamos uma nova figura para a nuvem de palavras com o tamanho 10x5.
plt.figure(figsize=(10, 5))

# Exibimos a nuvem de palavras gerada.
# 'bilinear' é uma técnica de interpolação para suavizar a imagem.
plt.imshow(wordcloud, interpolation='bilinear')

# Removemos os eixos da visualização para deixar a nuvem de palavras mais limpa.
plt.axis('off')

# Mostramos o gráfico com a nuvem de palavras.
plt.show()

# %%
# Importamos 'get_single_color_func' para permitir a personalização das cores na nuvem de palavras
from wordcloud import get_single_color_func

# Exemplo de uma função de cor personalizada que define a cor das palavras na nuvem de palavras
# A função recebe vários parâmetros (word, font_size, etc.) e retorna uma cor RGB específica.
def cor_personalizada(word, font_size, position, orientation, random_state=None, **kwargs):
    # Definimos uma cor personalizada (azul) para todas as palavras usando a notação RGB
    return 'rgb(50, 150, 255)'  # Cor azul em RGB

# Criamos a nuvem de palavras com a função de cor personalizada
# A cor de fundo é branca e usamos a função 'cor_personalizada' para definir a cor das palavras
wordcloud = WordCloud(width=3000, height=2000, background_color='white', color_func=cor_personalizada).generate_from_frequencies(freq_dist)

# Plotamos a nuvem de palavras
plt.figure(figsize=(10, 5))

# Exibimos a nuvem de palavras gerada com interpolação bilinear
plt.imshow(wordcloud, interpolation='bilinear')

# Removemos os eixos da visualização
plt.axis('off')

# Mostramos o gráfico com a nuvem de palavras
plt.show()

# %%
# Comando para instalar a biblioteca NumPy, que é usada para manipulação de arrays e dados numéricos.
# !pip install numpy

# %%
# Importamos a classe Image do módulo PIL (Python Imaging Library) para abrir e manipular imagens.
from PIL import Image

# Importamos a biblioteca NumPy para manipulação de arrays.
import numpy as np

# Carregamos a imagem "blz.png" e a convertemos para um array NumPy.
# Esse array será usado como máscara na criação de uma nuvem de palavras.
mascara = np.array(Image.open("dados/blz.png"))

# %%
# A variável 'mascara' contém um array NumPy que representa a imagem "blz.png".
# Cada valor no array corresponde a um pixel da imagem, e esse array pode ser usado para definir
# a forma da nuvem de palavras (WordCloud) ao invés de usar uma forma retangular padrão.
mascara

# %%
# Criamos uma nuvem de palavras utilizando a máscara 'mascara'.
# Definimos o tamanho da nuvem (3000x2000), cor de fundo preta, e o esquema de cores 'rainbow'.
# A máscara (mask=mascara) molda a nuvem de palavras conforme a imagem fornecida.
# 'collocations=False' evita a combinação de palavras frequentes, e 'stopwords' remove palavras irrelevantes.
wordcloud_mascara = WordCloud(
    width=3000, 
    height=2000, 
    random_state=1, 
    background_color='black', 
    colormap='rainbow', 
    collocations=False, 
    stopwords=STOPWORDS, 
    mask=mascara
).generate(texto)

# 'generate(texto)' cria a nuvem de palavras a partir do texto fornecido.

# %%
# Criamos uma nova figura para exibir a nuvem de palavras.
# O tamanho da figura é definido como 20x10, e a cor de fundo da área ao redor da nuvem de palavras é amarela (facecolor="Yellow").
plt.figure(figsize=(20, 10), facecolor="Yellow")

# Exibimos a nuvem de palavras gerada com a máscara personalizada.
plt.imshow(wordcloud_mascara)

# Removemos os eixos para que apenas a nuvem de palavras seja visível.
plt.axis("off")

# Ajustamos o layout para remover espaçamentos adicionais (pad = 0) ao redor da nuvem de palavras.
plt.tight_layout(pad=0)

# Exibimos a nuvem de palavras na tela.
plt.show()
